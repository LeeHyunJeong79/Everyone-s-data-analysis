# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')#그래프에 격자무늬 추가
plt.scatter([1,2,3,4],[10,20,30,40])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')#그래프에 격자무늬 추가
plt.scatter([1,2,3,4],[10,20,30,40],s=[100,200,250,300])#버블차트 추가(숫자에 따라 크기 변동)
plt.show()

# %%
#147~148
import matplotlib.pyplot as plt
plt.style.use('ggplot')#그래프에 격자무늬 추가
plt.scatter([1,2,3,4],[10,30,20,40],s=[30,60,90,120],c=['red','blue','green','gold'])#버블차트 추가(숫자에 따라 크기 변동)
plt.show()

# %%
#148~149
import matplotlib.pyplot as plt
plt.style.use('ggplot')#그래프에 격자무늬 추가
plt.scatter([1,2,3,4],[10,30,20,40],s=[30,60,90,120],c=['red','blue','green','gold'])#버블차트 추가(숫자에 따라 크기 변동)
plt.show()

# %%
#148
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[10,30,20,40],s=[30,60,90,120],c=range(4))
plt.colorbar()
plt.show()

# %%
#149
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[10,30,20,40],s=[30,60,90,120],c=range(4),cmap='jet')
plt.colorbar()
plt.show()
