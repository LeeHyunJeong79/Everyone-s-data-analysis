# %%
import csv
f=open('age.csv')
data=csv.reader(f)

for row in data:
    if row[0]=='서울특별시 강남구 대치1동(1168060000)':
        print(row)
# Out:
# ['서울특별시 강남구 대치1동(1168060000)', '24889 ', '24889 ', '1979 ', '5530 ', '2468 ', '1564 ', '6133 ', '3811 ', '1928 ', '1047 ', '349 ', '66 ', '14 ']

# %%
import csv
f=open('age.csv')
data=csv.reader(f)

for row in data:
    if '압구정' in row[0]:
        print(row)
# Out:
# ['서울특별시 강남구 압구정동(1168054500)', '27270 ', '27270 ', '2146 ', '2819 ', '3191 ', '3386 ', '4880 ', '4112 ', '3157 ', '2436 ', '962 ', '163 ', '18 ']

# %%
import csv
f=open('age.csv')
data=csv.reader(f)
result=[]
for row in data:
    if '압구정' in row[0]:
        for i in range(3,14):
            result.append(row[i])
print(result)
# Out:
# ['2146 ', '2819 ', '3191 ', '3386 ', '4880 ', '4112 ', '3157 ', '2436 ', '962 ', '163 ', '18 ']

# %%
import csv
f=open('age.csv')
data=csv.reader(f)
result=[]
for row in data:
    if '압구정' in row[0]:
        for i in range(3,14):
           print(row[i])
           result.append(int(row[i]))
print(result)

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(result)
plt.show()
# Out:
# 2146
# 2819
# 3191
# 3386
# 4880
# 4112
# 3157
# 2436
# 962
# 163
# 18
# [2146, 2819, 3191, 3386, 4880, 4112, 3157, 2436, 962, 163, 18]

# %%
import csv
f=open('age.csv')
data=csv.reader(f)
result=[]
for row in data:
    if '동안구 부흥' in row[0]:
        for i in row[3:]:
            result.append(int(i))
print(result)                          
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(result)
plt.show()
# Out:
# [1445, 2261, 2129, 2223, 3320, 2772, 2037, 908, 456, 62, 2]
